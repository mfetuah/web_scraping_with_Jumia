# %% [markdown]
# # Web Scraping on Jumia.

# %%
#This is the link to the jumiaa site
#'https://www.jumia.com.gh/men-sneakers/'

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.jumia.com.gh/men-sneakers/'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'
}

# Send a GET request to the URL
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

product = soup.find_all('a', class_='core')

# %%
print(product)
# Out:
# [<a class="core" data-brand="Fashion" data-category="Fashion/Men's Fashion/Shoes/Fashion Sneakers" data-dimension23="16863" data-dimension26="456" data-dimension27="4.1" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|COL_111|CP_11|CTO|Camp_28|JA23|TBOOST" data-dimension44="0" data-id="FA114FS0LUNM6NAFAMZ" data-list="" data-name="Low Top Lace Up Sneakers - Blue" data-position="1" data-price="7.89" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/low-top-shoes-lace-up-sneakers-blue-fashion-mpg457136.html"><div class="img-c"><img alt="" class="img" data-lazy="true" data-src="https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/36/702222/1.jpg?4932" height="208" src="..." width="208"/><span class="bdg _xs camp" style="color:#FFFFFF;background:#03BE03;">✆0302740642 to Order</span></div><div class="info"><h3 class="name">Fashion Low Top Lace Up Sneakers - Blue</h3><div class="prc">GH₵ 99.00</div><div class="s-prc-w"><div class="old">GH₵ 194.00 - GH₵ 200.00</div><div class="bdg _dsct _sm">51%</div></div><div class="rev"><div class="stars _s">4.1 out of 5<div class="in" style="width:81.99999999999999%"></div></div>(456)</div><svg aria-label="Express Shipping" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.gh/assets_he/images/i-shop-jumia.9f5451c7.svg#express"></use></svg></div></a>, <a class="core" data-brand="Fashion" data-category="Fashion/Men's Fashion/Shoes/Fashion Sneakers/Sneakers/Low-cut" data-dimension23="16863" data-dimension26="912" data-dimension27="4.1" data-dimension28="1" data-dimension37="0" data-dimension43="Boost|COL_111|CP_11|CTO|Camp_28|JA23|POD" data-dimension44="0" data-id="WH489SH0XDXU7NAFAMZ" data-list="" data-name="Casual Lace-Up Sneakers - Blue/White" data-position="2" data-price="8.77" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/fashion-casual-lace-up-sneakers-bluewhite-11777065.html"><div class="img-c"><img alt="" class="img" data-lazy="true" data-src="https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/56/077711/1.jpg?8916" height="208" src="..." width="208"/><span class="bdg _xs camp" style="color:#FFFFFF;background:#FF0000;">Pay On Delivery</span></div><div class="info"><h3 class="name">Fashion Casual Lace-Up Sneakers - Blue/White</h3><div class="prc">GH₵ 110.00</div><div class="s-prc-w"><div class="old">GH₵ 175.00</div><div class="bdg _dsct _sm">37%</div></div><div class="rev"><div class="stars _s">4.1 out of 5<div class="in" style="width:81.99999999999999%"></div></div>(912)</div><svg aria-label="Express Shipping" class="ic xprss" height="10" viewbox="0 0 114 12" width="94"><use xlink:href="https://www.jumia.com.gh/assets_he/images/i-shop-jumia.9f5451c7.svg#express"></use></svg></div></a>, <a class="core" data-brand="White Label" data-category="Fashion/Men's Fashion/Shoes/Fashion Sneakers" data-dimension23="11669" data-dimension26="8" data-dimension27="4" data-dimension28="0" data-dimension37="0" data-dimension43="Boost|CP_UN6|CTO|Camp_9|JA23|JA23_01" data-dimension44="0" data-id="WH489FS201PIONAFAMZ" data-list="" data-name="Tip Athletic Unisex Sneakers - Black" data-position="3" data-price="4.69" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/white-label-tip-athletic-unisex-sneakers-black-108021012.html"><div class="img-c"><img alt="" class="img" data-lazy="true" data-src="https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/21/0120801/1.jpg?9932" height="208" src="..." width="208"/><span class="bdg _xs camp" style="color:#FFFFFF;background:#03BE03;">✆0302740642 to Order</span></div><div class="info"><h3 class="name">Tip Athletic Unisex Sneakers - Black</h3><div class="prc">GH₵ 58.90 - GH₵ 61.75</div><div class="s-prc-w"><div class="old">GH₵ 100.00</div><div class="bdg _dsct _sm">41%</div></div><div class="rev"><div class="stars _s">4 out of 5<div class="in" style="width:80%"></div></div>(8)</div></div></a>, <a  ...

# %%
import pandas as pd

# %%
data  = []

for items in product:
    product_name = items.find('h3', class_='name').text.strip()
    image_url = items.find('img')['data-src']
    product_price = items.find('div', class_='prc').text.strip()
    product_discount = items.find('div', class_='bdg')
    product_rating = items.find('div', class_='stars _s').text.strip()
    product_old_price = items.find('div', class_='old').text.strip()
    delivery_method = items.find('span', class_='bdg _xs camp')

    #product_shipping = items.find('svg')['aria-label']
    
    if delivery_method:
        delivery_method = delivery_method.text.strip()

    if product_discount:
        discount = product_discount.text.strip()
        
    else:
        discount = 'No discount'

        
    #split Product into Product name and color
    product_parts = product_name.split('-')

    product_name = product_parts[0].strip()
    color = product_parts[-1].strip() if len(product_parts) > 1 else None
    
    
    
    print('Product Name:', product_name)
    print('Color:', color)
    print('Image_URL:', image_url)
    print('Price:', product_price)
    print('Old_Price:', product_old_price)
    print('Discount:', discount)
    print('Rating:', product_rating)  
    
    print('Delivery_Method:', delivery_method)
    

    
    #print('Shipping:', product_shipping)

    # Create a DataFrame from the extracted information
    product_data = {
    'Product': product_name,
    'Color':color,
    'Price': product_price,
    'Old_Price': product_old_price,
    'Discount': discount,
    'Rating': product_rating,    
    'Delivery_Method': delivery_method,
    'Image_URL': image_url
    }

    # Append the product data to the empty list
    data.append(product_data)

    # Create a DataFrame from the list of dictionaries
    df = pd.DataFrame(data)
# Out:
# Product Name: Fashion Low Top Lace Up Sneakers
# Color: Blue
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/36/702222/1.jpg?4932
# Price: GH₵ 99.00
# Old_Price: GH₵ 194.00 - GH₵ 200.00
# Discount: 51%
# Rating: 4.1 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Casual Lace
# Color: Blue/White
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/56/077711/1.jpg?8916
# Price: GH₵ 110.00
# Old_Price: GH₵ 175.00
# Discount: 37%
# Rating: 4.1 out of 5
# Delivery_Method: Pay On Delivery
# Product Name: Tip Athletic Unisex Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/21/0120801/1.jpg?9932
# Price: GH₵ 58.90 - GH₵ 61.75
# Old_Price: GH₵ 100.00
# Discount: 41%
# Rating: 4 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Lace Up Sneakers Men's Shoes
# Color: Blue/White
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/24/237711/1.jpg?9868
# Price: GH₵ 115.00
# Old_Price: GH₵ 156.00
# Discount: 26%
# Rating: 4 out of 5
# Delivery_Method: Pay On Delivery
# Product Name: Casual Low Top Lace Up Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/58/512846/1.jpg?1452
# Price: GH₵ 49.99 - GH₵ 54.00
# Old_Price: GH₵ 75.60 - GH₵ 100.00
# Discount: 50%
# Rating: 3.8 out of 5
# Delivery_Method: Pay On Delivery
# Product Name: Luxury Design Sneakers
# Color: Brown
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/17/666949/1.jpg?6279
# Price: GH₵ 60.00
# Old_Price: GH₵ 100.00
# Discount: 40%
# Rating: 4.1 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Casual Breathable Lace Up Low Top Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/47/420793/1.jpg?1540
# Price: GH₵ 80.00
# Old_Price: GH₵ 156.00
# Discount: 49%
# Rating: 4.2 out of 5
# Delivery_Method: None
# Product Name: Casual Low Top Lace Up Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/07/938605/1.jpg?1363
# Price: GH₵ 49.99
# Old_Price: GH₵ 100.00
# Discount: 50%
# Rating: 3.7 out of 5
# Delivery_Method: Pay On Delivery
# Product Name: On Point Low
# Color: Black/White
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/93/17694/1.jpg?2135
# Price: GH₵ 65.00
# Old_Price: GH₵ 130.00
# Discount: 50%
# Rating: 4.1 out of 5
# Delivery_Method: Pay On Delivery
# Product Name: Luxury Design Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/02/666949/1.jpg?6280
# Price: GH₵ 60.00
# Old_Price: GH₵ 100.00
# Discount: 40%
# Rating: 4 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Low
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/29/25175/1.jpg?6867
# Price: GH₵ 59.00 - GH₵ 65.00
# Old_Price: GH₵ 79.00
# Discount: 25%
# Rating: 3.8 out of 5
# Delivery_Method: Pay On Delivery
# Product Name: Fashion Wear
# Color: White
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/59/444445/1.jpg?6232
# Price: GH₵ 85.00
# Old_Price: GH₵ 148.00
# Discount: 43%
# Rating: 4.3 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Casual Canvas Shoes
# Color: Gray
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/08/229413/1.jpg?9462
# Price: GH₵ 79.00
# Old_Price: GH₵ 154.00
# Discount: 49%
# Rating: 3.8 out of 5
# Delivery_Method: Pay On Delivery
# Product Name: Fashion Breathable Slip
# Color: Grey
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/73/638115/1.jpg?7332
# Price: GH₵ 90.00
# Old_Price: GH₵ 176.00
# Discount: 49%
# Rating: 3.9 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Slip On Casual Sneakers
# Color: Khaki/Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/28/364525/1.jpg?6833
# Price: GH₵ 115.00
# Old_Price: GH₵ 229.00
# Discount: 50%
# Rating: 4.3 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Unisex Fitzip Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/68/898664/1.jpg?8552
# Price: GH₵ 58.90 - GH₵ 62.00
# Old_Price: GH₵ 70.00 - GH₵ 100.00
# Discount: 38%
# Rating: 3.6 out of 5
# Delivery_Method: None
# Product Name: Flex Athletic Unisex Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/31/0120801/1.jpg?9994
# Price: GH₵ 58.90 - GH₵ 61.75
# Old_Price: GH₵ 100.00
# Discount: 41%
# Rating: 4.6 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Breathable Glow In The Dark Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/09/444445/1.jpg?6233
# Price: GH₵ 72.00
# Old_Price: GH₵ 141.00
# Discount: 49%
# Rating: 4.1 out of 5
# Delivery_Method: None
# Product Name: Fashion Low Top Canvas Sneaker
# Color: Gray
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/60/4348111/1.jpg?6768
# Price: GH₵ 62.00
# Old_Price: GH₵ 79.00
# Discount: 22%
# Rating: 4.4 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Mens Sneakers Low Top Canvas Shoes
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/06/8129601/1.jpg?2592
# Price: GH₵ 109.00
# Old_Price: GH₵ 199.00
# Discount: 45%
# Rating: 4 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Men Casual High
# Color: Top Walking Sneakers Work Shoes
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/07/9315211/1.jpg?0609
# Price: GH₵ 136.00 - GH₵ 145.00
# Old_Price: GH₵ 200.00 - GH₵ 225.00
# Discount: 40%
# Rating: 4 out of 5
# Delivery_Method: None
# Product Name: Simple Fashion Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/91/766949/1.jpg?6278
# Price: GH₵ 49.99
# Old_Price: GH₵ 75.60
# Discount: 34%
# Rating: 3.9 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Fashion Shoes Men Sneakers Shoes
# Color: None
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/70/4348111/1.jpg?6768
# Price: GH₵ 69.00
# Old_Price: GH₵ 79.00
# Discount: 13%
# Rating: 5 out of 5
# Delivery_Method: None
# Product Name: Fashion Elegant Sneakers
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/80/4348111/1.jpg?6767
# Price: GH₵ 69.00
# Old_Price: GH₵ 79.00
# Discount: 13%
# Rating: 3.8 out of 5
# Delivery_Method: ✆0302740642 to Order
# Product Name: Low
# Color: Black
# Image_URL: https://gh.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/37/8614/1.jpg?3163
# Price: GH₵ 65.00
# Old_Price: GH₵ 120.00
# Discount: 46%
# Rating: 3.7 out of 5
# Delivery_Method: None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 8
#       6 product_price = items.find('div', class_='prc').text.strip()
#       7 product_discount = items.find('div', class_='bdg')
# ----> 8 product_rating = items.find('div', class_='stars _s').text.strip()
#       9 product_old_price = items.find('div', class_='old').text.strip()
#      10 delivery_method = items.find('span', class_='bdg _xs camp')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df
# Out:
#                                               Product  \
# 0                    Fashion Low Top Lace Up Sneakers
# 1                                 Fashion Casual Lace
# 2                        Tip Athletic Unisex Sneakers
# 3                Fashion Lace Up Sneakers Men's Shoes
# 4                     Casual Low Top Lace Up Sneakers
# 5                              Luxury Design Sneakers
# 6   Fashion Casual Breathable Lace Up Low Top Snea...
# 7                     Casual Low Top Lace Up Sneakers
# 8                                        On Point Low
# 9                              Luxury Design Sneakers
# 10                                                Low
# 11                                       Fashion Wear
# 12                        Fashion Casual Canvas Shoes
# 13                            Fashion Breathable Slip
# 14                    Fashion Slip On Casual Sneakers
# 15                             Unisex Fitzip Sneakers
# 16                      Flex Athletic Unisex Sneakers
# 17       Fashion Breathable Glow In The Dark Sneakers
# 18                     Fashion Low Top Canvas Sneaker
# 19         Fashion Mens Sneakers Low Top Canvas Shoes
# 20                            Fashion Men Casual High
# 21                            Simple Fashion Sneakers
# 22                   Fashion Shoes Men Sneakers Shoes
# 23                           Fashion Elegant Sneakers
# 24                                                Low
#
#                               Color                    Price  \
# 0                              Blue                GH₵ 99.00
# 1                        Blue/White               GH₵ 110.00
# 2                             Black    GH₵ 58.90 - GH₵ 61.75
# 3                        Blue/White               GH₵ 115.00
# 4                             Black    GH₵ 49.99 - GH₵ 54.00
# 5                             Brown                GH₵ 60.00
# 6                             Black                GH₵ 80.00
# 7                             Black                GH₵ 49.99
# 8                       Black/White                GH₵ 65.00
# 9                             Black                GH₵ 60.00
# 10                            Black    GH₵ 59.00 - GH₵ 65.00
# 11                            White                GH₵ 85.00
# 12                             Gray                GH₵ 79.00
# 13                             Grey                GH₵ 90.00
# 14                      Khaki/Black               GH₵ 115.00
# 15                            Black    GH₵ 58.90 - GH₵ 62.00
# 16                            Black    GH₵ 58.90 - GH₵ 61.75
# 17                            Black                GH₵ 72.00
# 18                             Gray                GH₵ 62.00
# 19                            Black               GH₵ 109.00
# 20  Top Walking Sneakers Work Shoes  GH₵ 136.00 - GH₵ 145.00
# 21                            Black                GH₵ 49.99
# 22                             None                GH₵ 69.00
# 23                            Black                GH₵ 69.00
# 24                            Black                GH₵ 65.00
#
#                   Old_Price Discount        Rating       Delivery_Method  \
# 0   GH₵ 194.00 - GH₵ 200.00      51%  4.1 out of 5  ✆0302740642 to Order
# 1                GH₵ 175.00      37%  4.1 out of 5       Pay On Delivery
# 2                GH₵ 100.00      41%    4 out of 5  ✆0302740642 to Order
# 3                GH₵ 156.00      26%    4 out of 5       Pay On Delivery
# 4    GH₵ 75.60 - GH₵ 100.00      50%  3.8 out of 5       Pay On Delivery
# 5                GH₵ 100.00      40%  4.1 out of 5  ✆0302740642 to Order
# 6                GH₵ 156.00      49%  4.2 out of 5                  None
# 7                GH₵ 100.00      50%  3.7 out of 5       Pay On Delivery
# 8                GH₵ 130.00      50%  4.1 out of 5       Pay On Delivery
# 9                GH₵ 100.00      40%    4 out of 5  ✆0302740642 to Order
# 10                GH₵ 79.00      25%  3.8 out of 5       Pay On Delivery
# 11               GH₵ 148.00      43%  4.3 out of 5  ✆0302740642 to Order
# 12               GH₵ 154.00      49%  3.8 out of 5       Pay On Delivery
# 13               GH₵ 176.00      49%  3.9 out of 5  ✆0302740642 to Order
# 14               GH₵ 229.00      50%  4.3 out of 5  ✆0302740642 to Order
# 15   GH₵ 70.00 - GH₵ 100.00      38%  3.6 out of 5                  None
# 16               GH₵ 100.00      41%  4.6 out of 5  ✆0302740642 to Order
# 17               GH₵ 141.00      49%  4.1 out of 5                  None
# 18                GH₵ 79.00      22%  4.4 out of 5  ✆0302740642 to Order
# 19               GH₵ 199.00      45%    4 out of 5  ✆0302740642 to Order
# 20  GH₵ 200.00 - GH₵ 225.00      40%    4 out of 5                  None
# 21                GH₵ 75.60      34%  3.9 out of 5  ✆0302740642 to Order
# 22                GH₵ 79.00      13%    5 out of 5                  None
# 23                GH₵ 79.00      13%  3.8 out of 5  ✆0302740642 to Order
# 24               GH₵ 120.00      46%  3.7 out of 5                  None
#
#                                             Image_URL
# 0   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 1   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 2   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 3   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 4   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 5   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 6   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 7   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 8   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 9   https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 10  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 11  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 12  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 13  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 14  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 15  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 16  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 17  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 18  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 19  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 20  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 21  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 22  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 23  https://gh.jumia.is/unsafe/fit-in/300x300/filt...
# 24  https://gh.jumia.is/unsafe/fit-in/300x300/filt...

# %%
# Save the DataFrame to a CSV file
df.to_csv('jumia_data.csv', index=False)
